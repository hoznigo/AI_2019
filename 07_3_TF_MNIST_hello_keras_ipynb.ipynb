# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# x_train = x_train / 255.0
# x_test = x_train / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(256, activation=tf.nn.relu),
  #tf.keras.layers.Dense(256, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5) # 5라는 숫자는 hyperparameter이다. / data를 다 소진한다는 의미가 epochs이다.
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.2261 - acc: 0.9347
# Epoch 2/5
# 60000/60000 [==============================] - 8s 131us/sample - loss: 0.0919 - acc: 0.9723
# Epoch 3/5
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.0606 - acc: 0.9817
# Epoch 4/5
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.0436 - acc: 0.9865
# Epoch 5/5
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.0321 - acc: 0.9900

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# #### TEST ACCURACY

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 55us/sample - loss: 0.0661 - acc: 0.9789
# [0.06614277740219841, 0.9789]

# %%
model.evaluate(x_test[:2], y_test[:2]) # 일부분만 test해 보는 것
# Out:
# 2/2 [==============================] - 0s 889us/sample - loss: 1.4841e-05 - acc: 1.0000
# [1.4841446500213351e-05, 1.0]

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### TRAINING ACCURACY

# %%
model.evaluate(x_train, y_train)
# Out:
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0202 - acc: 0.9941
# [0.020160749269160443, 0.99405]

# %%
model.summary()
# Total paprams는 flatten의 shape에 10을 곱하고 dense의 shape를 더해준다.
# flatten은 weight에 곱해주는 것이고, bias는 dense의 값을 더해준다.
# dense를 기억해 놓을 것 - 차후 시험에는 미표시
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# ...
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
401920/512
# Out:
# 785.0

# %%
784*512
# Out:
# 401408

# %%
401920-401408
# Out:
# 512

# %%
784*512+512
# Out:
# 401920

# %%
512*10+10
# Out:
# 5130

# %%
784*512+512+512*10+10
# Out:
# 407050

# %% [markdown]
# ### *Real World Challenge*: Large difference between training and testing set accuracy
